# %%
import pandas_datareader.data as web
import datetime
import pandas as pd
import pandas_datareader as pdr
import numpy as np
import pickle

# %%
df = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download', header=0)[0]

# %%
df
# Out:
#            회사명    종목코드               업종  \
# 0         JS전선    5560    절연선 및 케이블 제조업
# 1        거북선2호  101380              NaN
# 2        거북선6호  114140              NaN
# 3        교보메리츠   64900              NaN
# 4       국제관광공사   28780              NaN
# ...        ...     ...              ...
# 3895        툴젠  199800  자연과학 및 공학 연구개발업
# 3896  플럼라인생명과학  222670  자연과학 및 공학 연구개발업
# 3897   피엔에이치테크  239890      기초 화학물질 제조업
# 3898  한국미라클피플사  331660      기타 화학제품 제조업
# 3899       휴벡셀  212310       의료용 기기 제조업
#
#                                                    주요제품         상장일  결산월  \
# 0                                    선박선,고무선,전력선,통신선 제조  2007-11-12  12월
# 1                                           운송장비(선박) 임대  2008-04-25  12월
# 2                                                   NaN  2009-10-01  12월
# 3                                             부동산 투자,운용  2002-01-30  12월
# 4                                                   NaN  1966-03-18  12월
# ...

# %%
codes = df['종목코드']

# %%
codes
# Out:
# 0         5560
# 1       101380
# 2       114140
# 3        64900
# 4        28780
#          ...
# 3895    199800
# 3896    222670
# 3897    239890
# 3898    331660
# 3899    212310
# Name: 종목코드, Length: 3900, dtype: int64

# %%
codes_str = []

# %%
for idx, c in enumerate(codes):
    add_zero = 6 - len(str(c))
    codes_str.append('0'*add_zero + str(c))

# %%
codes_str
# Out:
# ['005560',
#  '101380',
#  '114140',
#  '064900',
#  '028780',
#  '085450',
#  '000470',
#  '000980',
#  '028930',
#  '014740',
#  '019930',
#  '016390',
#  '014080',
#  '004130',
#  '009030',
#  '004420',
#  '001830',
#  '083370',
#  '083390',
#  '083120',
#  '029230',
#  '000090',
#  '010530',
#  '035590',
#  '028400',
#  '008890',
#  '004740',
#  '029150',
#  '003400',
#  '003940',
#  '000730',
#  '007910',
#  '011450',
#  '004190',
#  '028980',
#  '018690',
#  '000010',
#  '008190',
#  '012190',
#  '082260',
#  '083580',
#  '083590',
#  '083620',
#  '034180',
#  '003190',
#  '001970',
#  '017300',
#  '012720',
#  '900030',
#  '002850',
#  '008640',
#  '029110',
#  '012050',
#  '103130',
#  '007050',
#  '012260',
#  '005020',
#  '012500',
#  '000610',
#  '034380',
#  '005600',
#  '008990',
#  '094950',
#  '004620',
#  '028560',
#  '090970',
#  '019300',
#  '140890',
#  '014590',
#  '063350',
#  '028360',
#  '034580',
#  '028380',
#  '028750',
#  '010150',
#  '014430',
# ...

# %%
c='005930'
try:
    gs = web.DataReader(str(c)+'.KS', 'yahoo')
    print(c,'success')
except:
    print(c,"failed")
try:
    gs = web.DataReader(str(c)+'.KQ', 'yahoo')
    print(c,'success')
except:
    print(c,"failed")
try:
    gs = web.DataReader(str(c), 'yahoo')
    print(c,'success')
except:
    print(c,"failed")
# Out:
# 005930 success
# 005930 failed
# 005930 failed

# %%
for c in codes_str[:5]:
    try:
        gs = web.DataReader(c+'.KS', 'yahoo')
        print(c,'success')
    except:
        print(c,"failed")
    try:
        gs = web.DataReader(c+'.KQ', 'yahoo')
        print(c,'success')
    except:
        print(c,"failed")
# Out:
# 005560 failed
# 005560 failed
# 101380 failed
# 101380 failed
# 114140 failed
# 114140 failed
# 064900 failed
# 064900 failed
# 028780 failed
# 028780 failed

# %%
c='005560'
try:
    gs = web.DataReader(str(c)+'.KS', 'yahoo')
    print(c,'success')
except:
    print(c,"failed")
try:
    gs = web.DataReader(str(c)+'.KQ', 'yahoo')
    print(c,'success')
except:
    print(c,"failed")
try:
    gs = web.DataReader(str(c), 'yahoo')
    print(c,'success')
except:
    print(c,"failed")
# Out:
# 005560 failed
# 005560 failed
# 005560 failed

# %%
df.iloc[0]
# Out:
# 회사명                         JS전선
# 종목코드                        5560
# 업종                 절연선 및 케이블 제조업
# 주요제품          선박선,고무선,전력선,통신선 제조
# 상장일                   2007-11-12
# 결산월                          12월
# 대표자명                         이익희
# 홈페이지    http://www.jscable.co.kr
# 지역                          충청남도
# Name: 0, dtype: object

# %%
codes_str[0]

# %%
c='005935'
try:
    gs = web.DataReader(str(c)+'.KS', 'yahoo')
    print(c,'success')
except:
    print(c,"failed")
try:
    gs = web.DataReader(str(c)+'.KQ', 'yahoo')
    print(c,'success')
except:
    print(c,"failed")
try:
    gs = web.DataReader(str(c), 'yahoo')
    print(c,'success')
except:
    print(c,"failed")
# Out:
# 005935 success
# 005935 failed
# 005935 failed

# %%
codes_from_csv=[]
for c in df_pd['000020 ????']:
    codes_from_csv.append(c.split(' ')[0])

# %%
codes_from_csv
# Out:
# ['000030',
#  '000040',
#  '000050',
#  '000060',
#  '000070',
#  '000075',
#  '000080',
#  '000087',
#  '000100',
#  '000105',
#  '000120',
#  '000140',
#  '000145',
#  '000150',
#  '000155',
#  '000157',
#  '000180',
#  '000210',
#  '000215',
#  '000220',
#  '000225',
#  '000227',
#  '000230',
#  '000240',
#  '000250',
#  '000270',
#  '000300',
#  '000320',
#  '000325',
#  '000327',
#  '000370',
#  '000390',
#  '000400',
#  '000430',
#  '000440',
#  '000480',
#  '000490',
#  '000500',
#  '000520',
#  '000540',
#  '000545',
#  '000547',
#  '000590',
#  '000640',
#  '000650',
#  '000660',
#  '000670',
#  '000680',
#  '000700',
#  '000720',
#  '000725',
#  '000760',
#  '000810',
#  '000815',
#  '000850',
#  '000860',
#  '000880',
#  '000885',
#  '000890',
#  '000910',
#  '000950',
#  '000970',
#  '000990',
#  '000995',
#  '001000',
#  '001020',
#  '001040',
#  '001045',
#  '001060',
#  '001065',
#  '001067',
#  '001070',
#  '001080',
#  '001120',
#  '001130',
#  '001140',
# ...

# %%
for c in codes_from_csv[:5]:
    try:
        gs = web.DataReader(c+'.KS', 'yahoo')
        print(c,'success')
    except:
        print(c,"failed")
    try:
        gs = web.DataReader(c+'.KQ', 'yahoo')
        print(c,'success')
    except:
        print(c,"failed")
# Out:
# 000030 failed
# 000030 failed
# 000040 success
# 000040 failed
# 000050 success
# 000050 failed
# 000060 success
# 000060 failed
# 000070 success
# 000070 failed

# %%
codes_from_csv.append('000020')

# %%
with open('codes.pickle','wb') as f:
    pickle.dump(codes_from_csv,f)

# %%
df_pd =pd.read_csv('codes.csv')

# %%
df_pd
# Out:
#                                 000020 ????
# 0                               000030 ????
# 1                              000040 KR???
# 2                                 000050 ??
# 3                              000060 ?????
# 4                              000070 ?????
# ...                                     ...
# 2285                             900290 GRT
# 2286                          950110 SBI???
# 2287                          950130 ??????
# 2288                    950140 ?????(Reg.S)
# 2289  [??] ????? ???? ??????|??? ??? ??? ??
#
# [2290 rows x 1 columns]
